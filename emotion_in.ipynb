# %% [markdown]
# <a href="https://colab.research.google.com/github/SachinStarman/webtools/blob/main/emotion_in.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This is a notebook for training emotion classification from input audio for the robo pet Wini

# %%
# !pip install "numpy<2.0"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 88.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.90 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# pytensor 2.37.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install torch==2.2.2 torchaudio==2.2.2 --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 757.2/757.2 MB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 118.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 112.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 66.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 132.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 14.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.8 MB/s eta 0:00:00
# ...

# %%
# !pip uninstall -y torchcodec torchaudio
# Out:
# WARNING: Skipping torchcodec as it is not installed.
# Found existing installation: torchaudio 2.9.0+cu126
# Uninstalling torchaudio-2.9.0+cu126:
#   Successfully uninstalled torchaudio-2.9.0+cu126

# %%
pip install torchaudio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 13.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 915.7/915.7 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 89.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 103.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 9.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 73.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 87.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 5.8 MB/s eta 0:00:00
# ...

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from collections import Counter
from sklearn.metrics import recall_score

from ravcnnprog import create_dataloaders
from fivefeatcnnatten3 import CNN_BiLSTM_Attention
import os

SAVE_DIR = "saved_models"
os.makedirs(SAVE_DIR, exist_ok=True)

SAVE_PATH = os.path.join(SAVE_DIR, "best_cnn_bilstm_attention.pth")


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

EPOCHS = 20
LR = 1e-4
BATCH_SIZE = 16
NUM_CLASSES = 5

root = "/content/drive/MyDrive/Emotion_fold/RAVDESS"
train_loader, val_loader, test_loader = create_dataloaders(root)

all_labels = []
for _, y in train_loader:
    all_labels.extend(y.tolist())

label_counts = Counter(all_labels)
total = sum(label_counts.values())

class_weights = torch.tensor(
    [total / label_counts[i] for i in range(NUM_CLASSES)],
    dtype=torch.float
).to(device)

print("Class weights:", class_weights)

model = CNN_BiLSTM_Attention(num_classes=NUM_CLASSES).to(device)

criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = optim.Adam(model.parameters(), lr=LR)


def compute_uar(model, dataloader, device):
    model.eval()

    all_preds = []
    all_labels = []

    with torch.no_grad():
        for x, y in dataloader:
            x = x.to(device)
            y = y.to(device)

            outputs, _ = model(x)
            preds = torch.argmax(outputs, dim=1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(y.cpu().numpy())

    # UAR = macro recall
    uar = recall_score(all_labels, all_preds, average="macro")
    return uar


best_val_loss = float("inf")

for epoch in range(EPOCHS):
    # -------- TRAIN --------
    model.train()
    train_loss = 0.0

    for x, y in train_loader:
        x = x.to(device)
        y = y.to(device)

        optimizer.zero_grad()

        outputs, _ = model(x)
        loss = criterion(outputs, y)

        loss.backward()
        optimizer.step()

        train_loss += loss.item()

    train_loss /= len(train_loader)

    # -------- VALIDATION --------
    model.eval()
    val_loss = 0.0

    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device)
            y = y.to(device)

            outputs, _ = model(x)
            loss = criterion(outputs, y)

            val_loss += loss.item()

    val_loss /= len(val_loader)
    val_uar = compute_uar(model, val_loader, device)

    print(
        f"Epoch [{epoch+1}/{EPOCHS}] "
        f"Train Loss: {train_loss:.4f} "
        f"Val Loss: {val_loss:.4f}"
        f"Val UAR: {val_uar:.4f}"
    )

    # -------- SAVE BEST MODEL --------
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), SAVE_PATH)
        print("✅ Best model saved")
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.12/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.12/dist-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
# ...

# %%
import torch

from fivefeatcnnatten3 import CNN_BiLSTM_Attention
from ravcnnprog import create_dataloaders

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = CNN_BiLSTM_Attention(num_classes=5).to(device)
model.load_state_dict(
    torch.load(
        "saved_models/best_cnn_bilstm_attention.pth",
        map_location=device
    )
)
model.eval()

print("✅ Model loaded successfully")

# %%
from ravcnnprog import load_audio, extract_mel
IDX_TO_EMOTION = {
    0: "neutral",
    1: "happy",
    2: "sad",
    3: "angry",
    4: "surprised"
}
def predict_single_audio(audio_path):
    waveform = load_audio(audio_path)
    mel = extract_mel(waveform)        # (1, 128, T)
    mel = mel.unsqueeze(0).to(device)  # (1, 1, 128, T)

    with torch.no_grad():
        logits, attn = model(mel)
        pred = torch.argmax(logits, dim=1).item()

    return IDX_TO_EMOTION[pred], attn
emotion, attention = predict_single_audio(
    "/content/drive/MyDrive/MovithProgFiles/Emotion_fold/RAVDESS/Actor_05/03-01-04-01-02-02-05.wav"  # example
)

print("Predicted emotion:", emotion)

# %%
from sklearn.metrics import recall_score
def compute_uar(model, dataloader, device):
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for x, y in dataloader:
            x = x.to(device)
            y = y.to(device)

            outputs, _ = model(x)
            preds = torch.argmax(outputs, dim=1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(y.cpu().numpy())

    return recall_score(all_labels, all_preds, average="macro")
# Create loaders again
root = "/content/drive/MyDrive/MovithProgFiles/Emotion_fold/RAVDESS"
_, _, test_loader = create_dataloaders(root)

test_uar = compute_uar(model, test_loader, device)
print("✅ Test UAR:", test_uar)

# %%
def count_params(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print("Trainable parameters:", count_params(model))

# %%
pip install sounddevice soundfile

# %%
pip install librosa

# %%
import librosa
import numpy as np

y, sr = librosa.load("movithneutralaudio.mp4", sr=16000)

print("Sample rate:", sr)
print("Audio shape:", y.shape)

# %%
mel = librosa.feature.melspectrogram(
    y=y,
    sr=sr,
    n_mels=64,
    n_fft=1024,
    hop_length=512
)

log_mel = librosa.power_to_db(mel, ref=np.max)

print(log_mel.shape)

# %%
import librosa
import numpy as np

SR = 16000

def extract_features(wav_path):
    y, sr = librosa.load(wav_path, sr=SR)

    mel = librosa.feature.melspectrogram(
        y=y,
        sr=sr,
        n_mels=64,
        n_fft=1024,
        hop_length=512
    )

    log_mel = librosa.power_to_db(mel, ref=np.max)
    return log_mel

# %%
features = extract_features("movithneutralaudio.mp4")
print(features.shape)

# %%
from ravcnnprog import load_audio, extract_mel
IDX_TO_EMOTION = {
    0: "neutral",
    1: "happy",
    2: "sad",
    3: "angry",
    4: "surprised"
}
def predict_single_audio(audio_path):
    waveform = load_audio(audio_path)
    mel = extract_mel(waveform)        # (1, 128, T)
    mel = mel.unsqueeze(0).to(device)  # (1, 1, 128, T)

    with torch.no_grad():
        logits, attn = model(mel)
        pred = torch.argmax(logits, dim=1).item()

    return IDX_TO_EMOTION[pred], attn
emotion, attention = predict_single_audio(
    "movithangryaudio3sec.mp4"  # example
)

print("Predicted emotion:", emotion)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-3985620187.py in <cell line: 0>()
# ----> 1 from ravcnnprog import load_audio, extract_mel
#       2 IDX_TO_EMOTION = {
#       3     0: "neutral",
#       4     1: "happy",
#       5     2: "sad",
#
# ModuleNotFoundError: No module named 'ravcnnprog'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
